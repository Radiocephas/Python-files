# %%
# Library and Book Aggregation

class Book:
    def __init__(self, title, author):
        self.title = title
        self.author = author
    

class Library:
    def __init__(self):
        self.books = []

    def add_book(self, book):
        self.books.append(book)
    
    def display_books(self):
        for book in self.books:
            return f"{book.title}: {book.author}"
    
library = Library()

book1 = Book("Data Structures", "Narasimha Karumanchi")
book2 = Book("Automate the Boring Stuff", "Al Sweigartz")
book3 = Book("Clean Code", "Robert C. Martin")
book4 = Book("Think Python", "Allen B. Downey")

library.add_book(book1)
library.add_book(book2)
library.add_book(book3)

print(library.display_books())

# %%
class Book:
    def __init__(self, title, author, copies_available):
        self.title = title
        self.author = author
        self.copies_available = copies_available

    def borrow_copy(self):
        if self.copies_available > 0:
            self.copies_available -= 1
            return True
        return False

    def __str__(self):
        return f"{self.title} by {self.author}"


class Library:
    def __init__(self):
        self.books = []

    def add_book(self, book):
        self.books.append(book)

    def lend_book(self, title):
        for book in self.books:
            if book.title == title and book.copies_available > 0:
                success = book.borrow_copy()
                if success:
                    return book
        return None


class Student:
    def __init__(self, name):
        self.name = name
        self.borrowed_books = []

    def borrow_from_library(self, library, title):
        book = library.lend_book(title)
        if book:
            self.borrowed_books.append(book)
            print(f"{self.name} borrowed '{book.title}' by {book.author}")
        else:
            print(f"{self.name} could not borrow '{title}' - Not available")

    def show_borrowed_books(self):
        if self.borrowed_books:
            print(f"{self.name} has borrowed:")
            for book in self.borrowed_books:
                print(f" - {book}")
        else:
            print(f"{self.name} has not borrowed any books.")


# Example usage
book1 = Book("Python Crash Course", "Eric Matthes", 2)
book2 = Book("Deep Learning", "Ian Goodfellow", 1)

library = Library()
library.add_book(book1)
library.add_book(book2)

student1 = Student("Alice")
student2 = Student("Bob")

student1.borrow_from_library(library, "Python Crash Course")
student2.borrow_from_library(library, "Deep Learning")
student2.borrow_from_library(library, "Python Crash Course")
student2.borrow_from_library(library, "Python Crash Course")  # No more copies

print()
student1.show_borrowed_books()
print()
student2.show_borrowed_books()

# %%
class Book:
    def __init__(self, title, author):
        self.title = title
        self.author = author


class Library:
    def __init__(self):
        self.books = []

    def add_book(self, book):
        self.books.append(book)
    
    def display_books(self):
        result = ""
        for book in self.books:
            result += f"{book.title}: {book.author}\n"
        return result.strip()


library = Library()

book1 = Book("Data Structures", "Narasimha Karumanchi")
book2 = Book("Automate the Boring Stuff", "Al Sweigartz")
book3 = Book("Clean Code", "Robert C. Martin")

library.add_book(book1)
library.add_book(book2)
library.add_book(book3)

print(library.display_books())

# %%
class Movie:
    def __init__(self, title, director, genre):
        self.title = title
        self.director = director
        self.genre = genre
    
    def __str__(self):
        return f"Title: {self.title}, Director: {self.director}, Genre: {self.genre}"

class Store:
    def __init__(self):
        self.available_movies = []

    def add_movie(self, movie):
        self.available_movies.append(movie)

    def list_available_movies(self):
        avail_movies = ''
        for movie in self.available_movies:
            avail_movies += f"Title: {movie.title}, Director: {movie.director}, Genre: {movie.genre}\n"
        return avail_movies.strip()

class Customer:
    pass



movie1 = Movie(title="Inception", director="Christopher Nolan", genre="Sci-Fi")
movie2 = Movie("The Matrix", "Lana Wachowski & Lilly Wachowski", "Action")
movie3 = Movie("Interstellar", "Christopher Nolan", "Sci-Fi")
movie4 = Movie("Parasite", "Bong Joon-ho", "Thriller")
movie5 = Movie("The Godfather", "Francis Ford Coppola", "Crime")
movie6 = Movie("Spirited Away", "Hayao Miyazaki", "Animation")
movie7 = Movie("The Shawshank Redemption", "Frank Darabont", "Drama")
movie8 = Movie("Pulp Fiction", "Quentin Tarantino", "Crime")

store = Store()
store.add_movie(movie1)
store.add_movie(movie2)
store.add_movie(movie3)
store.add_movie(movie4)
store.add_movie(movie5)

print(store.list_available_movies())
