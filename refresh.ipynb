# %%
a = int(input("Enter first number: "))
b =  int(input("Enter second number: "))
avg = (a+b)/2
print(f"The average {a} and {b} is {avg}")
# Out:
# The average 5 and 6 is 5.5

# %%
print ("George","Weah")
# Out:
# George Weah

# %%
c =  float(input("Enter the temperature in degrees: "))
f =  (c * 9/5) + 32
print(f"{c} degrees celcius is equal to {f} fahrenheit")
# Out:
# 60.0 degrees celcius is equal to 140.0 fahrenheit

# %%
r = int(input("Enter the radius of the circle: "))
c =  2 * 3.142 * r
print(f"The circumference of the cirlce with radius {r}cm long is {c:2f}")
# Out:
# The circumference of the cirlce with radius 5cm long is 31.420000

# %%
ch = input(print("Enter any character"))

if ch.isalpha():
    print("Character is alphabet")
if ch.isdigit():
    print("Character is digit")
# Out:
# Enter any character

# %%
vowels = ["a", "e", "i", "o", "u"]
ch = input("Enter character: ")

if ch in vowels:
    print("Character is a vowel")
else:
    print("Character is not a vowel")
# Out:
# Character is not a vowel

# %%
i = 1
total = 0
while (i<=10):
    total += i
    i += 1

print(total)
# Out:
# 55

# %%
n = int(input("Enter any number: "))
count = 0

while n > 0:
    count += 1
    n //= 10

print("Count of digits:", count)
# Out:
# Count of digits: 8

# %%
n = int(input("Enter any integer: "))

for i in range(1, n+1):
     i **= 3
     print(i)
# Out:
# 1
# 8
# 27
# 64
# 125
# 216
# 343
# 512
# 729
# 1000

# %%
n = int(input())
i = 1

while(i<=12):
    print(f"{n} x {i} = {n * i}")
    i += 1
# Out:
# 10 x 1 = 10
# 10 x 2 = 20
# 10 x 3 = 30
# 10 x 4 = 40
# 10 x 5 = 50
# 10 x 6 = 60
# 10 x 7 = 70
# 10 x 8 = 80
# 10 x 9 = 90
# 10 x 10 = 100
# 10 x 11 = 110
# 10 x 12 = 120
